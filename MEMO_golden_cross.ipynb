# %% [markdown]
# # 	1y n493 golden Cross
#
# ## no condition
# ##  s5, l20
# g_p_count	3573
# roc_d1_plus	1777
# roc_d3_plus	1766
# roc_d5_plus	1740
# roc_d10_plus	1884
#
# roc_d1_plus: sum    0.497341
# roc_d3_plus: sum    0.494263
# roc_d5_plus: sum    0.486986
# roc_d10_plus: sum    0.527288
#
# # s5,l25
# g_p_count	3067
# roc_d1_plus	1520
# roc_d3_plus	1536
# roc_d5_plus	1498
# roc_d10_plus	1587
#
# roc_d1_plus: sum    0.495598
# roc_d3_plus: sum    0.500815
# roc_d5_plus: sum    0.488425
# roc_d10_plus: sum    0.517444
#
#
# # s5,l50
# g_p_count	1756
# roc_d1_plus	846
# roc_d3_plus	836
# roc_d5_plus	826
# roc_d10_plus	831
#
# roc_d1_plus: sum    0.481777
# roc_d3_plus: sum    0.476082
# roc_d5_plus: sum    0.470387
# roc_d10_plus: sum    0.473235
#
# ##  s5, l75
# g_p_count	1191
# roc_d1_plus	590
# roc_d3_plus	562
# roc_d5_plus	529
# roc_d10_plus	606
#
# roc_d1_plus: sum    0.495382
# roc_d3_plus: sum    0.471872
# roc_d5_plus: sum    0.444165
# roc_d10_plus: sum    0.508816
#
# # short plus long minus
#
# g_p_count	1673
# roc_d1_plus	862
# roc_d3_plus	816
# roc_d5_plus	809
# roc_d10_plus	882
#
# roc_d1_plus: sum    0.515242
# roc_d3_plus: sum    0.487747
# roc_d5_plus: sum    0.483562
# roc_d10_plus: sum    0.527197
#
#
# # short plus long plus
#
# g_p_count	1771
# roc_d1_plus	864
# roc_d3_plus	890
# roc_d5_plus	876
# roc_d10_plus	938
#
# roc_d1_plus: sum    0.48786
# roc_d3_plus: sum    0.502541
# roc_d5_plus: sum    0.494636
# roc_d10_plus: sum    0.529644
#
#  # deg 30
# g_p_count	351
# roc_d1_plus	169
# roc_d3_plus	169
# roc_d5_plus	171
# roc_d10_plus	174
#
# roc_d1_plus: sum    0.481481
# roc_d3_plus: sum    0.481481
# roc_d5_plus: sum    0.487179
# roc_d10_plus: sum    0.495726
#
# # deg 45
# g_p_count	208
# roc_d1_plus	96
# roc_d3_plus	96
# roc_d5_plus	98
# roc_d10_plus	96
#
# roc_d1_plus: sum    0.461538
# dtype: float64 roc_d3_plus: sum    0.461538
# dtype: float64 roc_d5_plus: sum    0.471154
# dtype: float64 roc_d10_plus: sum    0.461538
#
# # deg60
# # s5, l20
#
# g_p_count	108
# roc_d1_plus	45
# roc_d3_plus	48
# roc_d5_plus	52
# roc_d10_plus	47
#
# roc_d1_plus: sum    0.416667
# roc_d3_plus: sum    0.444444
# roc_d5_plus: sum    0.481481
# roc_d10_plus: sum    0.435185
#
#  # s5 l25 n数も少なくそれなりに高い。ほかの指標と組合せてみてもよいかも
#  g_p_count	124
# roc_d1_plus	68
# roc_d3_plus	68
# roc_d5_plus	64
# roc_d10_plus	69
#
#  roc_d1_plus: sum    0.548387
# roc_d3_plus: sum    0.548387
# roc_d5_plus: sum    0.516129
# roc_d10_plus: sum    0.556452
#
# # s5 l70
# g_p_count	70
# roc_d1_plus	34
# roc_d3_plus	30
# roc_d5_plus	31
# roc_d10_plus	33
#
# roc_d1_plus: sum    0.485714
# dtype: float64 roc_d3_plus: sum    0.428571
# dtype: float64 roc_d5_plus: sum    0.442857
# dtype: float64 roc_d10_plus: sum    0.471429
#
#  # s5 l75
#  g_p_count	55
# roc_d1_plus	25
# roc_d3_plus	25
# roc_d5_plus	22
# roc_d10_plus	31
#
# roc_d1_plus: sum    0.454545
# roc_d3_plus: sum    0.454545
# roc_d5_plus: sum    0.4
# roc_d10_plus: sum    0.563636
