# %% [markdown]
# # 	1y n493 golden Cross
#
# ## s 12 days l = 26 days signal =9 days
# ## no condition
#
# g_p_count	5343
# roc_d1_plus	2662
# roc_d3_plus	2687
# roc_d5_plus	2688
# roc_d10_plus	2777
#
# roc_d1_plus: sum    0.498222
# roc_d3_plus: sum    0.502901
# roc_d5_plus: sum    0.503088
# roc_d10_plus: sum    0.519745
#
# ## s 8 days l = 17 days signal =9 days
#  g_p_count	6609
# roc_d1_plus	3316
# roc_d3_plus	3378
# roc_d5_plus	3402
# roc_d10_plus	3499
#
# roc_d1_plus: sum    0.50174
#  roc_d3_plus: sum    0.511121
# roc_d5_plus: sum    0.514753
# roc_d10_plus: sum    0.52943
#
#  # deg 30
#  sum
# g_p_count	4443
# roc_d1_plus	2233
# roc_d3_plus	2238
# roc_d5_plus	2239
# roc_d10_plus	2296
#
# roc_d1_plus: sum    0.502588
# roc_d3_plus: sum    0.503714
# roc_d5_plus: sum    0.503939
# roc_d10_plus: sum    0.516768
#
# # deg 45
# 	sum
# g_p_count	3566
# roc_d1_plus	1789
# roc_d3_plus	1798
# roc_d5_plus	1773
# roc_d10_plus	1828
#
# roc_d1_plus: sum    0.501683
# roc_d3_plus: sum    0.504206
# roc_d5_plus: sum    0.497196
# roc_d10_plus: sum    0.512619
#
#
# # deg60
# g_p_count	2298
# roc_d1_plus	1157
# roc_d3_plus	1168
# roc_d5_plus	1134
# roc_d10_plus	1158
#
# roc_d1_plus: sum    0.503481
# roc_d3_plus: sum    0.508268
#  roc_d5_plus: sum    0.493473
# roc_d10_plus: sum    0.503916
#
#
# # deg60 + 0.01% position
# g_p_count	1594
# roc_d1_plus	800
# roc_d3_plus	808
# roc_d5_plus	779
# roc_d10_plus	780
#
# roc_d1_plus: sum    0.501882
# dtype: float64 roc_d3_plus: sum    0.506901
# dtype: float64 roc_d5_plus: sum    0.488708
# dtype: float64 roc_d10_plus: sum    0.489335
# dtype: float64
# # deg60 + 0.01% position
# ## s 6 days l = 19 days signal =4 days
#
#
# ## s 6 days l = 19 days signal =9 days
# g_p_count	1863
# roc_d1_plus	913
# roc_d3_plus	945
# roc_d5_plus	976
# roc_d10_plus	977
#
# roc_d1_plus: sum    0.49007
# roc_d3_plus: sum    0.507246
#  roc_d5_plus: sum    0.523886
#  roc_d10_plus: sum    0.524423
#
#
# # deg60 + 0.01% position
# ## s 8 days l = 17 days signal =9 days
# g_p_count	2119
# roc_d1_plus	1072
# roc_d3_plus	1090
# roc_d5_plus	1080
# roc_d10_plus	1110
#
# roc_d1_plus: sum    0.505899
# dtype: float64 roc_d3_plus: sum    0.514394
# dtype: float64 roc_d5_plus: sum    0.509674
# dtype: float64 roc_d10_plus: sum    0.523832
# dtype: float64
