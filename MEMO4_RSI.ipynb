# %% [markdown]
# # cut off 30%
#
#    buy_sign_count  roc_d1_plus  roc_d3_plus  roc_d5_plus  roc_d10_plus
# 0            2602         1233         1407         1484          1477
# 1             755          366          425          457           461
# 2             145           71           87          107            91
# 3               3            3            2            2             2
#
# p_9_roc_d1_plus 0.4738662567255957
# p_9_roc_d3_plus 0.5407378939277478
# p_9_roc_d5_plus 0.5703305149884704
# p_9_roc_d10_plus 0.5676402767102229
#
# p_14_roc_d1_plus 0.4847682119205298
# p_14_roc_d3_plus 0.5629139072847682
# p_14_roc_d5_plus 0.6052980132450331
# p_14_roc_d10_plus 0.6105960264900663
#
# p_22_roc_d1_plus 0.4896551724137931
# p_22_roc_d3_plus 0.6
# p_22_roc_d5_plus 0.7379310344827587
# p_22_roc_d10_plus 0.6275862068965518
#
# p_42_roc_d1_plus 1.0
# p_42_roc_d3_plus 0.6666666666666666
# p_42_roc_d5_plus 0.6666666666666666
# p_42_roc_d10_plus 0.6666666666666666
#
# # cut off 25%
#
#
# buy_sign_count	roc_d1_plus	roc_d3_plus	roc_d5_plus	roc_d10_plus
# 0	1171	574	641	683	680
# 1	220	105	123	135	133
# 2	33	22	22	26	22
# 3	0	0	0	0	0
#
# p_9_roc_d1_plus 0.4901793339026473
# p_9_roc_d3_plus 0.547395388556789
# p_9_roc_d5_plus 0.5832621690862511
# p_9_roc_d10_plus 0.5807002561912895
#
# p_14_roc_d1_plus 0.4772727272727273
# p_14_roc_d3_plus 0.5590909090909091
# p_14_roc_d5_plus 0.6136363636363636
# p_14_roc_d10_plus 0.6045454545454545
#
# p_22_roc_d1_plus 0.6666666666666666
# p_22_roc_d3_plus 0.6666666666666666
# p_22_roc_d5_plus 0.7878787878787878
# p_22_roc_d10_plus 0.6666666666666666
#
# # cut off 20%
#
# buy_sign_count	roc_d1_plus	roc_d3_plus	roc_d5_plus	roc_d10_plus
# 0	423	198	253	264	253
# 1	36	16	20	19	21
# 2	2	1	2	2	2
# 3	0	0	0	0	0
#
# p_9_roc_d1_plus 0.46808510638297873
# p_9_roc_d3_plus 0.5981087470449172
# p_9_roc_d5_plus 0.624113475177305
# p_9_roc_d10_plus 0.5981087470449172
#
# p_14_roc_d1_plus 0.4444444444444444
# p_14_roc_d3_plus 0.5555555555555556
# p_14_roc_d5_plus 0.5277777777777778
# p_14_roc_d10_plus 0.5833333333333334
#
# p_22_roc_d1_plus 0.5
# p_22_roc_d3_plus 1.0
# p_22_roc_d5_plus 1.0
# p_22_roc_d10_plus 1.0
